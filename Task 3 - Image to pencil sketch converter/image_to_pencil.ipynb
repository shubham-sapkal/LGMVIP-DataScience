# %% [markdown]
# #LETS GROW MORE
#
# #*Name:* Shubham Sapkal
#
# # Data Science Intern
#
# #*Task-3:* Image to Pencil Sketch with Python

# %%
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %%
image = cv2.imread("/content/shreeman dada.jpg")
image
# Out:
# array([[[195, 103,   0],
#         [192, 100,   0],
#         [187,  96,   0],
#         ...,
#         [ 82, 118, 104],
#         [ 81, 117, 103],
#         [ 73, 112,  97]],
#
#        [[190, 107,   0],
#         [187, 104,   0],
#         [182, 100,   0],
#         ...,
#         [ 87, 123, 109],
#         [ 87, 123, 109],
#         [ 80, 119, 104]],
#
#        [[180, 115,  10],
#         [176, 110,   7],
#         [171, 105,   2],
#         ...,
#         [ 93, 129, 115],
#         [ 94, 130, 116],
#         [ 93, 129, 115]],
#
#        ...,
#
#        [[112, 128, 165],
#         [113, 129, 166],
#         [118, 130, 170],
#         ...,
#         [ 68,  77, 121],
#         [ 81,  90, 133],
#         [109, 119, 159]],
#
#        [[102, 117, 156],
#         [109, 124, 163],
#         [122, 134, 176],
#         ...,
#         [ 71,  79, 126],
#         [ 78,  87, 130],
#         [ 67,  76, 119]],
#
#        [[ 94, 106, 148],
#         [107, 119, 161],
#         [126, 137, 181],
#         ...,
#         [ 74,  82, 129],
#         [ 76,  85, 128],
#         [ 62,  71, 114]]], dtype=uint8)

# %% [markdown]
# # Showing Image

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=201x251 at 0x7F62596C7C50>

# %% [markdown]
# # Converting Image into Gray Scale Image

# %%
gray_scale_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_scale_image)
# Out:
# <PIL.Image.Image image mode=L size=201x251 at 0x7F6258DE4D90>

# %% [markdown]
# # Inverting the gray scale image

# %%
inverted_image = cv2.bitwise_not(gray_scale_image)
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=201x251 at 0x7F62596BE2D0>

# %% [markdown]
# # Image Smoothing

# %%
img_smoothing = cv2.GaussianBlur(inverted_image, (21, 21), sigmaX=0, sigmaY=0)
cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=201x251 at 0x7F6258DB7090>

# %% [markdown]
# # Final Step

# %%
def pencil_sketch(x, y):
  return cv2.divide(x, 255-y, scale=256)

# %%
pencilsketch = pencil_sketch(gray_scale_image, img_smoothing)
cv2_imshow(pencilsketch)
# Out:
# <PIL.Image.Image image mode=L size=201x251 at 0x7F6258DB74D0>
